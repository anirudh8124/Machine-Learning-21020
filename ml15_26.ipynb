# %%
import numpy as np
from sklearn import svm
from sklearn.model_selection import train_test_split

# have to use the  training and testing data in X_train, y_train, X_test, and y_test

#  Create an SVM classifier
clf = svm.SVC()

# Train the classifier using the training data
clf.fit(X_train, y_train)

# Get the support vectors (optional, for studying)
support_vectors = clf.support_vectors_

# Test the accuracy of the SVM using the test data
accuracy = clf.score(X_test, y_test)
print("Accuracy:", accuracy)


# Replace 'test_vect' with an actual feature vector from your test set
test_vect = [1.0, 2.0, 3.0]  # Replace with your test vector
predicted_class = clf.predict([test_vect])
print("Predicted Class:", predicted_class)
